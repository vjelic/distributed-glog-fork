# %%
import time
import os
import dask
import cupy
import xgboost as xgb
import dask.array as da
from distributed import Client
from dask_hip import LocalHIPCluster
from xgboost.dask import DaskDMatrix

# %%
def main(client):
    # generate some random data for demonstration
    n = 1_000
    m = 3_500_000
    partition_size = 10_000
    # m = n = 50_000
    # partition_size = 1_000
    rs = da.random.RandomState(RandomState=cupy.random.RandomState)
    x = rs.normal(size=(m, n), chunks=partition_size)
    y = rs.normal(size=(m,), chunks=partition_size)
 
    # DaskDMatrix acts like normal DMatrix, works as a proxy for local DMatrix scatter
    # around workers.
    dtrain = DaskDMatrix(client, x, y)

    # Use train method from xgboost.dask instead of xgboost.  This distributed version
    # of train returns a dictionary containing the resulting booster and evaluation
    # history obtained from evaluation metrics.
    start=time.time()
    output = xgb.dask.train(
        client,
        {
        "verbosity": 2,
        "tree_method": "hist",
        "device": "gpu",
                },
        dtrain,
        num_boost_round=8,
        evals=[(dtrain, "train")],
        )
    end=time.time()
    print(f'Train time: {end - start:.4f} secs')
    bst = output["booster"]
    history = output["history"]

    start = time.time()
    # you can pass output directly into `predict` too.
    prediction = xgb.dask.predict(client, bst, dtrain)
    end = time.time()
    print(f'Eval time: {end - start:.4f} secs')
    print("Evaluation history:", history)
    return prediction

# %%
# Set up Dask cluster & client, get dask dashboard

cluster = LocalHIPCluster(HIP_VISIBLE_DEVICES='0,1,2,3')
client = Client(cluster)
cluster
# Out:
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:42837
# INFO:distributed.scheduler:  dashboard at:            127.0.0.1:8787
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:38555'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:35387'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:46221'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:46631'
# 2023-11-09 03:52:57,616 - distributed.preloading - INFO - Creating preload: dask_hip.initialize
# 2023-11-09 03:52:57,616 - distributed.preloading - INFO - Import preload module: dask_hip.initialize
# 2023-11-09 03:52:57,649 - distributed.preloading - INFO - Creating preload: dask_hip.initialize
# 2023-11-09 03:52:57,649 - distributed.preloading - INFO - Import preload module: dask_hip.initialize
# 2023-11-09 03:52:57,653 - distributed.preloading - INFO - Creating preload: dask_hip.initialize
# 2023-11-09 03:52:57,653 - distributed.preloading - INFO - Import preload module: dask_hip.initialize
# 2023-11-09 03:52:57,655 - distributed.preloading - INFO - Creating preload: dask_hip.initialize
# 2023-11-09 03:52:57,655 - distributed.preloading - INFO - Import preload module: dask_hip.initialize
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:40835', name: 0, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:40835
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:40520
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:41215', name: 1, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:41215
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:40534
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:43915', name: 2, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:43915
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:40540
# INFO:distributed.scheduler:Register worker <WorkerState 'tcp://127.0.0.1:35843', name: 3, status: init, memory: 0, processing: 0>
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:35843
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:40554
# INFO:distributed.scheduler:Receive client connection: Client-78800d2b-7eb3-11ee-904e-368d33f8b47c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:40558
# LocalHIPCluster(764ad456, 'tcp://127.0.0.1:42837', workers=4, threads=4, memory=503.72 GiB)

# %%
# execute dask client
main(client)
# Out:
# INFO:distributed.worker:Run out-of-band function '_start_tracker'
# INFO:distributed.scheduler:Receive client connection: Client-worker-7f516713-7eb3-11ee-95d4-368d33f8b47c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39738
# INFO:distributed.scheduler:Receive client connection: Client-worker-7f513e50-7eb3-11ee-95d1-368d33f8b47c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39740
# INFO:distributed.scheduler:Receive client connection: Client-worker-7f518f1c-7eb3-11ee-95d7-368d33f8b47c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39746
# INFO:distributed.scheduler:Receive client connection: Client-worker-7f51f9f6-7eb3-11ee-95d8-368d33f8b47c
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:39752
# [03:53:09] task [xgboost.dask-0]:tcp://127.0.0.1:40835 got new rank 0
# [03:53:09] task [xgboost.dask-1]:tcp://127.0.0.1:41215 got new rank 1
# [03:53:09] task [xgboost.dask-2]:tcp://127.0.0.1:43915 got new rank 2
# [03:53:09] task [xgboost.dask-3]:tcp://127.0.0.1:35843 got new rank 3
# [03:53:10] INFO: /myhome/dask-dev/xgboost/src/data/simple_dmatrix.cc:135: Generating new Ellpack page.[03:53:10] INFO: /myhome/dask-dev/xgboost/src/data/simple_dmatrix.cc:135: Generating new Ellpack page.
#
# [03:53:10] INFO: /myhome/dask-dev/xgboost/src/data/simple_dmatrix.cc:135: Generating new Ellpack page.
# [03:53:10] INFO: /myhome/dask-dev/xgboost/src/data/simple_dmatrix.cc:135: Generating new Ellpack page.
# [0]	train-rmse:0.99973
# [1]	train-rmse:0.99965
# [2]	train-rmse:0.99957
# [3]	train-rmse:0.99949
# [4]	train-rmse:0.99941
# [5]	train-rmse:0.99934
# [6]	train-rmse:0.99925
# [7]	train-rmse:0.99917
# Train time: 2.8448 secs
# Eval time: 0.9371 secs
# Evaluation history: {'train': OrderedDict([('rmse', [0.9997349441670412, 0.9996505397780301, 0.9995735080402275, 0.9994889373917455, 0.9994081643112612, 0.999335568966786, 0.9992539293806494, 0.9991717997763842])])}
# dask.array<concatenate, shape=(3500000,), dtype=float32, chunksize=(10000,), chunktype=numpy.ndarray>

# %%
# Don't forget to clean-up after run

client.shutdown()
cluster.close()
# Out:
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:38555'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:35387'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:46221'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:46631'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.scheduler:Remove client Client-worker-7f513e50-7eb3-11ee-95d1-368d33f8b47c
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:39740; closing.
# INFO:distributed.scheduler:Remove client Client-worker-7f516713-7eb3-11ee-95d4-368d33f8b47c
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:39738; closing.
# INFO:distributed.scheduler:Remove client Client-worker-7f513e50-7eb3-11ee-95d1-368d33f8b47c
# INFO:distributed.scheduler:Remove client Client-worker-7f516713-7eb3-11ee-95d4-368d33f8b47c
# INFO:distributed.scheduler:Remove client Client-worker-7f518f1c-7eb3-11ee-95d7-368d33f8b47c
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:39746; closing.
# INFO:distributed.scheduler:Remove client Client-worker-7f518f1c-7eb3-11ee-95d7-368d33f8b47c
# INFO:distributed.scheduler:Remove client Client-worker-7f51f9f6-7eb3-11ee-95d8-368d33f8b47c
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:39752; closing.
# INFO:distributed.scheduler:Remove client Client-worker-7f51f9f6-7eb3-11ee-95d8-368d33f8b47c
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:40520; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:40534; closing.
# INFO:distributed.scheduler:Close client connection: Client-worker-7f513e50-7eb3-11ee-95d1-368d33f8b47c
# INFO:distributed.scheduler:Close client connection: Client-worker-7f516713-7eb3-11ee-95d4-368d33f8b47c
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:40835', name: 0, status: closing, memory: 196, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:40835
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:41215', name: 1, status: closing, memory: 140, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:41215
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:40540; closing.
# INFO:distributed.scheduler:Close client connection: Client-worker-7f518f1c-7eb3-11ee-95d7-368d33f8b47c
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:43915', name: 2, status: closing, memory: 180, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:43915
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:40554; closing.
# INFO:distributed.scheduler:Close client connection: Client-worker-7f51f9f6-7eb3-11ee-95d8-368d33f8b47c
# INFO:distributed.scheduler:Remove worker <WorkerState 'tcp://127.0.0.1:35843', name: 3, status: closing, memory: 184, processing: 0>
# INFO:distributed.core:Removing comms to tcp://127.0.0.1:35843
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.scheduler:Scheduler closing...
# INFO:distributed.scheduler:Scheduler closing all comms
